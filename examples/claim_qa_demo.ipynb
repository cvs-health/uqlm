# %% [markdown]
# # Claim-based Question-Answer Hallucination Detection

# %% [markdown]
# Import necessary packages.

# %%
import time
from uqlm.longform.black_box import ClaimQAScorer
from uqlm import BlackBoxUQ
from uqlm.utils.prompt_templates import get_claim_breakdown_template

# %% [markdown]
# #### Load LLM and device

# %%
# from langchain_google_vertexai import ChatVertexAI
# llm = ChatVertexAI(model="gemini-1.5-flash")

from dotenv import load_dotenv, find_dotenv
from langchain_openai import AzureChatOpenAI

load_dotenv(find_dotenv())
llm = AzureChatOpenAI(
    deployment_name="gpt-4o-mini",
    openai_api_type="azure",
    openai_api_version="2024-02-15-preview",
    temperature=1,  # User to set temperature
)

# %%
import torch

# Set the torch device
if torch.cuda.is_available():  # NVIDIA GPU
    device = torch.device("cuda")
elif torch.backends.mps.is_available():  # macOS
    device = torch.device("mps")
else:
    device = torch.device("cpu")  # CPU
print(f"Using {device.type} device")
# Out:
# Using mps device

# %% [markdown]
# #### Setup Prompts and Black Box Scorer

# %%
prompts = ["write a paragraph about Paul McCartney", 
           # "write a paragraph about John Lennon"
           ]

# %%
bb_scorer = BlackBoxUQ(
    llm=llm,
    max_calls_per_min=500,  # set value to avoid rate limit error
    device=device,
    scorers = ["semantic_negentropy", "exact_match"]
)

# %% [markdown]
# #### Claim-QA class

# %%
start_time = time.time()
claim_qa = ClaimQAScorer(llm=llm, bb_scorer=bb_scorer, response_template=get_claim_breakdown_template)
result = await claim_qa.generate_and_score(prompts=prompts)
print(f"Computation time: {time.time() - start_time} seconds")
# Out:
# ['Paul McCartney is an iconic British musician, singer, and songwriter, best known as a co-founder of the legendary rock band The Beatles. Born on June 18, 1942, in Liverpool, England, McCartney\'s melodic prowess and innovative songwriting played a pivotal role in the band\'s unprecedented success during the 1960s. His contributions to timeless hits like "Hey Jude," "Yesterday," and "Let It Be" remain integral to music history. After The Beatles disbanded in 1970, McCartney embarked on a successful solo career and formed the band Wings, further showcasing his versatility and staying power in the music industry. Beyond his musical achievements, McCartney is also known for his activism in animal rights and environmental issues, reflecting his deep commitment to social causes. His enduring influence and creativity continue to inspire generations of musicians and fans around the world.']
# Claim sets:  [['Paul McCartney is an iconic British musician.  \n', 'Paul McCartney is a singer.  \n', 'Paul McCartney is a songwriter.  \n', 'Paul McCartney is best known as a co-founder of the legendary rock band The Beatles.  \n', 'Paul McCartney was born on June 18, 1942.  \n', 'Paul McCartney was born in Liverpool, England.  \n', "Paul McCartney's melodic prowess played a pivotal role in The Beatles' unprecedented success.  \n", "Paul McCartney's innovative songwriting played a pivotal role in The Beatles' unprecedented success.  \n", 'The Beatles experienced unprecedented success during the 1960s.  \n', 'Paul McCartney contributed to timeless hits like "Hey Jude."  \n', 'Paul McCartney contributed to timeless hits like "Yesterday."  \n', 'Paul McCartney contributed to timeless hits like "Let It Be."  \n', "Paul McCartney's contributions remain integral to music history.  \n", 'Paul McCartney embarked on a successful solo career after The Beatles disbanded in 1970.  \n', 'Paul McCartney formed the band Wings.  \n', "Paul McCartney's work showcases his versatility in the music industry.  \n", "Paul McCartney's work showcases his staying power in the music industry.  \n", 'Paul McCartney is known for his activism in animal rights.  \n', 'Paul McCartney is known for his activism in environmental issues.  \n', "Paul McCartney's activism reflects his deep commitment to social causes.  \n", "Paul McCartney's enduring influence continues to inspire generations of musicians.  \n", "Paul McCartney's creativity continues to inspire generations of fans around the world."]]
# Prompt:
#
#     Following this text:
#
#     Paul McCartney is an iconic British musician, singer, and songwriter, best known as a co-founder of the legendary rock band The Beatles. Born on June 18, 1942, in Liverpool, England, McCartney's melodic prowess and innovative songwriting played a pivotal role in the band's unprecedented success during the 1960s. His contributions to timeless hits like "Hey Jude," "Yesterday," and "Let It Be" remain integral to music history. After The Beatles disbanded in 1970, McCartney embarked on a successful solo career and formed the band Wings, further showcasing his versatility and staying power in the music industry. Beyond his musical achievements, McCartney is also known for his activism in animal rights and environmental issues, reflecting his deep commitment to social causes. His enduring influence and creativity continue to inspire generations of musicians and fans around the world.
#
#     You see the sentence:
#
#     ['Paul McCartney is an iconic British musician.  \n', 'Paul McCartney is a singer.  \n', 'Paul McCartney is a songwriter.  \n', 'Paul McCartney is best known as a co-founder of the legendary rock band The Beatles.  \n', 'Paul McCartney was born on June 18, 1942.  \n', 'Paul McCartney was born in Liverpool, England.  \n', "Paul McCartney's melodic prowess played a pivotal role in The Beatles' unprecedented success.  \n", "Paul McCartney's innovative songwriting played a pivotal role in The Beatles' unprecedented success.  \n", 'The Beatles experienced unprecedented success during the 1960s.  \n', 'Paul McCartney contributed to timeless hits like "Hey Jude."  \n', 'Paul McCartney contributed to timeless hits like "Yesterday."  \n', 'Paul McCartney contributed to timeless hits like "Let It Be."  \n', "Paul McCartney's contributions remain integral to music history.  \n", 'Paul McCartney embarked on a successful solo career after The Beatles disbanded in 1970.  \n', 'Paul McCartney formed the band Wings.  \n', "Paul McCartney's work showcases his versatility in the music industry.  \n", "Paul McCartney's work showcases his staying power in the music industry.  \n", 'Paul McCartney is known for his activism in animal rights.  \n', 'Paul McCartney is known for his activism in environmental issues.  \n', "Paul McCartney's activism reflects his deep commitment to social causes.  \n", "Paul McCartney's enduring influence continues to inspire generations of musicians.  \n", "Paul McCartney's creativity continues to inspire generations of fans around the world."]
#
#     Generate a list of 2 questions, that might have generated the sentence in the context of the preceding original text, as well as their answers. Please do not use specific facts that appear in the follow-up sentence when formulating the question. Make the questions and answers diverse. Avoid yes-no questions. The answers should not be a full sentence and as short as possible, e.g. only a name, place, or thing. Output each question in one single line starting with ###. Do not include other formatting.
#
#     You should only return the final answer. Now your answer is:
#
# Questions:  {'responses': ['Hello! How can I assist you today?', 'Hello! How can I assist you today?', 'Hello! How can I assist you today?', 'Hello! It seems like your message was empty. How can I assist you today?', "Hello! It looks like you didn't type anything. How can I assist you today?", 'Hello! How can I assist you today?', 'Hello! How can I assist you today?', 'Hello! It seems like your message may be incomplete. How can I assist you today?', 'Hello! How can I assist you today?', 'Hello! How can I assist you today?', 'It seems that your message was cut off. How can I assist you today?', 'Hello! It seems like you might have started typing a message. How can I assist you today?', 'It looks like your message was incomplete. How can I assist you today?', 'Hello! It seems like you may have sent a message by mistake. How can I assist you today?', 'Hello! It seems like your message got cut off. How can I assist you today?', 'Hello! It seems like your message got cut off. How can I assist you today?', 'Hello! It seems like you might have pressed a key by accident. How can I assist you today?', 'It seems like your message got cut off. How can I assist you today?', 'Hello! It looks like you entered a single letter. How can I assist you today?', "Hello! It seems like your message didn't come through. How can I assist you today?", 'Hello! It seems like your message might not have come through completely. How can I assist you today?', 'Hello! How can I assist you today?', 'Hello! It looks like your message might have been cut off. How can I assist you today?', 'Hello! It looks like your message is incomplete. How can I assist you today?', 'Hello! How can I assist you today?', 'It seems like your message may have been cut off or you entered "t" by mistake. Could you please provide more information or clarify what you need help with?', 'Hello! It seems like your message got cut off. How can I assist you today?', 'Hello! It looks like you entered the letter "x." How can I assist you today? If you have a question or need information, feel free to ask!', 'Hello! It seems like your message might have been cut off. How can I assist you today?', 'Hello! How can I assist you today?', 'Hello! How can I assist you today?', 'Hello! It seems like your message might have been empty. How can I assist you today?', 'Hello! How can I assist you today? If you have any questions or need help with something, feel free to ask!', 'Hello! How can I assist you today?', 'Hello! How can I assist you today?', 'Hello! It seems your message may have been cut off or is blank. How can I assist you today?', 'Hello! How can I assist you today?', 'Hello! How can I assist you today?', 'Hello! It seems like your message may have been accidentally left blank. How can I assist you today?', 'Hello! It seems that your message didn’t come through. How can I assist you today?', 'Hello! It looks like you entered the letter "P." How can I assist you today? If you have a specific question or topic in mind, feel free to share!', 'Hello! It looks like you typed "a." How can I assist you today?', 'Hello! How can I assist you today?', 'Hello! It looks like your message might have been cut off. How can I assist you today?', 'Hello! How can I assist you today?', 'Hello! It looks like you entered just the letter "M." How can I assist you today? If you have any questions or topics in mind, feel free to share!', 'Hello! It looks like your message may have been cut off. How can I assist you today?', 'It seems like your message got cut off. How can I assist you with "C"? Are you looking for information about the programming language C, a particular concept, or something else? Please provide more details!', 'Hello! It seems like your message was cut off. How can I assist you today?', 'Hello! It seems like you entered a single letter "r." How can I assist you today? If you have a specific question or topic in mind, feel free to share!', 'Hello! It looks like your message got cut off. How c ...
# Questions:  []
# Final questions:  []
# No questions generated for factoid:  ['Paul McCartney is an iconic British musician.  \n', 'Paul McCartney is a singer.  \n', 'Paul McCartney is a songwriter.  \n', 'Paul McCartney is best known as a co-founder of the legendary rock band The Beatles.  \n', 'Paul McCartney was born on June 18, 1942.  \n', 'Paul McCartney was born in Liverpool, England.  \n', "Paul McCartney's melodic prowess played a pivotal role in The Beatles' unprecedented success.  \n", "Paul McCartney's innovative songwriting played a pivotal role in The Beatles' unprecedented success.  \n", 'The Beatles experienced unprecedented success during the 1960s.  \n', 'Paul McCartney contributed to timeless hits like "Hey Jude."  \n', 'Paul McCartney contributed to timeless hits like "Yesterday."  \n', 'Paul McCartney contributed to timeless hits like "Let It Be."  \n', "Paul McCartney's contributions remain integral to music history.  \n", 'Paul McCartney embarked on a successful solo career after The Beatles disbanded in 1970.  \n', 'Paul McCartney formed the band Wings.  \n', "Paul McCartney's work showcases his versatility in the music industry.  \n", "Paul McCartney's work showcases his staying power in the music industry.  \n", 'Paul McCartney is known for his activism in animal rights.  \n', 'Paul McCartney is known for his activism in environmental issues.  \n', "Paul McCartney's activism reflects his deep commitment to social causes.  \n", "Paul McCartney's enduring influence continues to inspire generations of musicians.  \n", "Paul McCartney's creativity continues to inspire generations of fans around the world."]  -- returning nan
# Factoids:  [[['Paul McCartney is an iconic British musician.  \n', 'Paul McCartney is a singer.  \n', 'Paul McCartney is a songwriter.  \n', 'Paul McCartney is best known as a co-founder of the legendary rock band The Beatles.  \n', 'Paul McCartney was born on June 18, 1942.  \n', 'Paul McCartney was born in Liverpool, England.  \n', "Paul McCartney's melodic prowess played a pivotal role in The Beatles' unprecedented success.  \n", "Paul McCartney's innovative songwriting played a pivotal role in The Beatles' unprecedented success.  \n", 'The Beatles experienced unprecedented success during the 1960s.  \n', 'Paul McCartney contributed to timeless hits like "Hey Jude."  \n', 'Paul McCartney contributed to timeless hits like "Yesterday."  \n', 'Paul McCartney contributed to timeless hits like "Let It Be."  \n', "Paul McCartney's contributions remain integral to music history.  \n", 'Paul McCartney embarked on a successful solo career after The Beatles disbanded in 1970.  \n', 'Paul McCartney formed the band Wings.  \n', "Paul McCartney's work showcases his versatility in the music industry.  \n", "Paul McCartney's work showcases his staying power in the music industry.  \n", 'Paul McCartney is known for his activism in animal rights.  \n', 'Paul McCartney is known for his activism in environmental issues.  \n', "Paul McCartney's activism reflects his deep commitment to social causes.  \n", "Paul McCartney's enduring influence continues to inspire generations of musicians.  \n", "Paul McCartney's creativity continues to inspire generations of fans around the world."]]]
# Response-level scores:  {'semantic_negentropy': [nan], 'exact_match': [nan]}
# Computation time: 195.36166882514954 seconds

# %% [markdown]
# #### Decomposition

# %%
from uqlm.longform import ResponseDecomposer

# %%
rd = ResponseDecomposer(llm)

# %%
responses = [
    "Hello there! Today I visited Dr. Chauhan at his home. He was hanging his framed B.S., M.S., and Ph.D. degrees. It was fun!",
    "One time I went on a class trip to D.C. to visit the white house. While there, I felt in awe of the beutiful art and important people with titles such as Prof., Esq., and others."
]

sampled_responses = [
    [
        "Hi! I went to see Dr. Chauhan at his house today. He was busy putting up his framed B.S., M.S., and Ph.D. diplomas. It was quite enjoyable!",
        "Greetings! Today, I stopped by Dr. Chauhan's home. He was in the process of displaying his framed degrees: B.S., M.S., and Ph.D. It was a delightful experience!"
    ],
    [
        "Once, I took a school trip to Washington, D.C. to see the White House. While I was there, I was amazed by the stunning artwork and the notable individuals with titles like Professor, Esquire, and more.",
        "During a class excursion to Washington, D.C., I had the opportunity to visit the White House. I was struck by the beautiful art and the distinguished people holding titles such as Prof., Esq., and others."
    ]
    
]

# %%
# Decompose into sentences
rd.decompose_sentences(responses=responses)
# Out:
# [['Hello there!',
#   'Today I visited Dr. Chauhan at his home.',
#   'He was hanging his framed B.S., M.S., and Ph.D. degrees.',
#   'It was fun!'],
#  ['One time I went on a class trip to D.C. to visit the white house.',
#   'While there, I felt in awe of the beutiful art and important people with titles such as Prof., Esq., and others.']]

# %%
# Decompose into claims
from uqlm.utils.prompt_templates import get_factoid_template
await rd.decompose_claims(responses=responses, response_template=get_factoid_template)
# Out:
# Claim sets:  [['The speaker visited Dr. Chauhan at his home today.  \n', 'Dr. Chauhan was hanging his framed B.S., M.S., and Ph.D. degrees.  \n', 'The visit was described as fun.  '], ['I went on a class trip to D.C. to visit the White House.  \n', 'While there, I felt in awe of the beautiful art.  \n', 'I felt in awe of important people with titles such as Prof., Esq., and others.']]
# [['The speaker visited Dr. Chauhan at his home today.  \n',
#   'Dr. Chauhan was hanging his framed B.S., M.S., and Ph.D. degrees.  \n',
#   'The visit was described as fun.  '],
#  ['I went on a class trip to D.C. to visit the White House.  \n',
#   'While there, I felt in awe of the beautiful art.  \n',
#   'I felt in awe of important people with titles such as Prof., Esq., and others.']]

# %%
from uqlm.utils.prompt_templates import get_claim_breakdown_template
await rd.decompose_claims(responses=responses, response_template=get_claim_breakdown_template)
# Out:
# Claim sets:  [['Today, I visited Dr. Chauhan at his home.  \n', 'I visited Dr. Chauhan.  \n', 'Dr. Chauhan is at his home.  \n', 'Dr. Chauhan was hanging his framed degrees.  \n', 'Dr. Chauhan was hanging his framed B.S. degree.  \n', 'Dr. Chauhan was hanging his framed M.S. degree.  \n', 'Dr. Chauhan was hanging his framed Ph.D. degree.  \n', 'It was fun.  '], ['I went on a class trip to D.C.  \n', 'I went to visit the White House.  \n', 'I felt in awe of the beautiful art.  \n', 'I felt in awe of important people.  \n', 'Important people have titles such as Prof., Esq., and others.  ']]
# [['Today, I visited Dr. Chauhan at his home.  \n',
#   'I visited Dr. Chauhan.  \n',
#   'Dr. Chauhan is at his home.  \n',
#   'Dr. Chauhan was hanging his framed degrees.  \n',
#   'Dr. Chauhan was hanging his framed B.S. degree.  \n',
#   'Dr. Chauhan was hanging his framed M.S. degree.  \n',
#   'Dr. Chauhan was hanging his framed Ph.D. degree.  \n',
#   'It was fun.  '],
#  ['I went on a class trip to D.C.  \n',
#   'I went to visit the White House.  \n',
#   'I felt in awe of the beautiful art.  \n',
#   'I felt in awe of important people.  \n',
#   'Important people have titles such as Prof., Esq., and others.  ']]
